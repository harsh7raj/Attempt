# %%
# !pip install git+https://github.com/harsh7raj/attempt.git
# Out:
# ...
#   Cloning https://github.com/harsh7raj/attempt.git to /private/var/folders/s9/mgfgmpwj3118whw9xbg5mzlr0000gn/T/pip-req-build-dmmvpjkh
#   Running command git clone --filter=blob:none --quiet https://github.com/harsh7raj/attempt.git /private/var/folders/s9/mgfgmpwj3118whw9xbg5mzlr0000gn/T/pip-req-build-dmmvpjkh
#   Resolved https://github.com/harsh7raj/attempt.git to commit 8236b1f39689d1bb6c29adcbd87cd3876af1ea6c
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for attemptpkg: filename=attemptpkg-0.1.0-py3-none-any.whl size=1456 sha256=283057b6c063340dd8c8536e5623823c107cff3367117b4875ffa37b65988697
#   Stored in directory: /private/var/folders/s9/mgfgmpwj3118whw9xbg5mzlr0000gn/T/pip-ephem-wheel-cache-l1hpkbjp/wheels/34/c5/49/089e9b550886b6b8e70821f53195982d35931d3525ca14e450
# Successfully built attemptpkg
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# ...

# %%
from attemptpkg.hello import say_hi
print(say_hi())
# Out:
# Hello from Harsh's package!
